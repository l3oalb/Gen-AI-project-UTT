# %% [markdown]
# Objectif : découper les pistes audio MP3 en extraits de 10 secondes

# %%
import os
import subprocess
import random

# Dossier contenant les fichiers audio
input_folder = "../Audios/Original_files"
# Dossier où sauvegarder les extraits
output_folder = "../Audios/Splited_files"

clip_min_sec = 10
clip_max_sec = 15

for filename in os.listdir(input_folder):
    if filename.endswith(".mp3"):
        input_path = os.path.join(input_folder, filename)
        
        # Obtenir la durée totale en secondes
        result = subprocess.run(
            ["ffprobe", "-i", input_path, "-show_entries", "format=duration",
             "-v", "quiet", "-of", "csv=p=0"],
            capture_output=True, text=True
        )
        total_duration = float(result.stdout.strip())
        
        start = 0
        part = 1
        while start < total_duration:
            clip_duration = random.randint(clip_min_sec, clip_max_sec)
            end = min(start + clip_duration, total_duration)
            
            output_path = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}_part{part}.mp3")
            
            subprocess.run([
                "ffmpeg", "-y", "-i", input_path,
                "-ss", str(start), "-to", str(end),
                "-c", "copy", output_path
            ])
            
            start += clip_duration
            part += 1

        print(f"{filename} découpé en {part-1} extraits")
# Out:
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.4.4.1)
# ...

# %%
import os 

for nom_fichier in os.listdir(output_folder):
    chemin_complet = os.path.join(output_folder, nom_fichier)

    if os.path.isfile(chemin_complet) and nom_fichier.lower().endswith(".mp3"):
        if "|" in nom_fichier:
            nouveau_nom = nom_fichier.replace("|", "_")
            nouveau_chemin = os.path.join(output_folder, nouveau_nom)
            os.rename(chemin_complet, nouveau_chemin)
            print(f"Renommé : {nom_fichier} -> {nouveau_nom}")
# Out:
# Renommé : The Goose and Its Golden Egg | Moral Stories | Animated Stories_part1.mp3 -> The Goose and Its Golden Egg _ Moral Stories _ Animated Stories_part1.mp3
# Renommé : The Goose and Its Golden Egg | Moral Stories | Animated Stories_part3.mp3 -> The Goose and Its Golden Egg _ Moral Stories _ Animated Stories_part3.mp3
# Renommé : The Goose and Its Golden Egg | Moral Stories | Animated Stories_part2.mp3 -> The Goose and Its Golden Egg _ Moral Stories _ Animated Stories_part2.mp3
# Renommé : The Goose and Its Golden Egg | Moral Stories | Animated Stories_part4.mp3 -> The Goose and Its Golden Egg _ Moral Stories _ Animated Stories_part4.mp3
# Renommé : Rabbit And Crow | One Minute Story | Childenzia English Story_part5.mp3 -> Rabbit And Crow _ One Minute Story _ Childenzia English Story_part5.mp3
# Renommé : Rabbit And Crow | One Minute Story | Childenzia English Story_part4.mp3 -> Rabbit And Crow _ One Minute Story _ Childenzia English Story_part4.mp3
# ...
